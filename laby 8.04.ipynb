# %%
import pandas as pd

dane = pd.read_csv('data/airbnb.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
# ----> 3 dane = pd.read_csv('data/airbnb.csv')
#
# File c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
dane.head(2)
# Out:
#    Unnamed: 0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
#
#     host_id host_name          neighbourhood_full            coordinates  \
# 0  20583125    Michel         Brooklyn, Flatlands  (40.63222, -73.93398)
# 1  82746113   Cecilia  Manhattan, Upper West Side  (40.78761, -73.96862)
#
#          room_type price  number_of_reviews last_review  reviews_per_month  \
# 0     Private room   45$                 10  2018-12-12                0.7
# 1  Entire home/apt  135$                  1  2019-06-30                1.0
#
#    availability_365    rating  number_of_stays   5_stars listing_added
# 0                85  4.100954             12.0  0.609432    2018-06-08
# 1               145  3.367600              1.2  0.746135    2018-12-25

# %%
dane.shape
# Out:
# (10019, 17)

# %%
dane.isna().sum()
# Out:
# Unnamed: 0               0
# listing_id               0
# name                     5
# host_id                  0
# host_name                2
# neighbourhood_full       0
# coordinates              0
# room_type                0
# price                  238
# number_of_reviews        0
# last_review           2075
# reviews_per_month     2075
# availability_365         0
# rating                2075
# number_of_stays       2075
# 5_stars               2075
# listing_added            0
# dtype: int64

# %%
#dane['price'] = dane['price'].str.strip("$")
#dane['price'] =head()
dane['price'] = dane['price'].astype('float')
dane['price'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #dane['price'] = dane['price'].str.strip("$")
#       2 #dane['price'] =head()
# ----> 3 dane['price'] = dane['price'].astype('float')
#       4 dane['price'].mean()
#
# NameError: name 'dane' is not defined

# %%
dane.head(3)
# Out:
#    Unnamed: 0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
# 2           2    21667615                  Beautiful 1BR in Brooklyn Heights
#
#     host_id host_name          neighbourhood_full            coordinates  \
# 0  20583125    Michel         Brooklyn, Flatlands  (40.63222, -73.93398)
# 1  82746113   Cecilia  Manhattan, Upper West Side  (40.78761, -73.96862)
# 2     78251    Leslie  Brooklyn, Brooklyn Heights   (40.7007, -73.99517)
#
#          room_type  price  number_of_reviews last_review  reviews_per_month  \
# 0     Private room   45.0                 10  2018-12-12                0.7
# 1  Entire home/apt  135.0                  1  2019-06-30                1.0
# 2  Entire home/apt  150.0                  0         NaN                NaN
#
# ...

# %%
avg = dane['price'].mean()
dane['price'].fillna(avg)
# Out:
# 0         45.0
# 1        135.0
# 2        150.0
# 3         86.0
# 4        160.0
#          ...
# 10014    105.0
# 10015    125.0
# 10016    100.0
# 10017    450.0
# 10018     90.0
# Name: price, Length: 10019, dtype: float64

# %%
dane.isna().sum() #powinno dla price byc 0 bledow (brakow)
# Out:
# Unnamed: 0               0
# listing_id               0
# name                     5
# host_id                  0
# host_name                2
# neighbourhood_full       0
# coordinates              0
# room_type                0
# price                  238
# number_of_reviews        0
# last_review           2075
# reviews_per_month     2075
# availability_365         0
# rating                2075
# number_of_stays       2075
# 5_stars               2075
# listing_added            0
# dtype: int64
